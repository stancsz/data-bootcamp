# %% [markdown]
# # What is DBT
# https://docs.getdbt.com/docs/introduction
# > dbt (data build tool) enables analytics engineers to transform data in their warehouses by simply writing select statements. dbt handles turning these select statements into tables and views.
# dbt does the T in ELT (Extract, Load, Transform) processes – it doesn’t extract or load data, but it’s extremely good at transforming data that’s already loaded into your warehouse.
# The role of dbt within a modern data stack is discussed in more detail here.
# dbt also enables analysts to work more like software engineers, in line with the dbt Viewpoint.

# %% [markdown]
# # Setup DBT
# based off official guide
#
# https://docs.getdbt.com/tutorial/setting-up

# %%
# !apt-get update
# !pip install \
  dbt-core \
  dbt-postgres \
  dbt-redshift \
  dbt-snowflake \
  dbt-bigquery \
  dbt-sqlite
# !dbt --version
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [917 kB]
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,826 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,564 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,470 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [936 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [21.1 kB]
# Get:22 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [783 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [29.0 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,004 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [816 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,248 kB]
# Get:27 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Get:28 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [42.8 kB]
# Fetched 15.0 MB in 7s (2,246 kB/s)
# Reading package lists... Done
# Collecting dbt-core
#   Downloading dbt_core-1.0.2-py3-none-any.whl (835 kB)
#      |████████████████████████████████| 835 kB 5.1 MB/s
# Collecting dbt-postgres
#   Downloading dbt_postgres-1.0.2-py3-none-any.whl (13 kB)
# Collecting dbt-redshift
#   Downloading dbt_redshift-1.0.0-py3-none-any.whl (17 kB)
# Collecting dbt-snowflake
#   Downloading dbt_snowflake-1.0.0-py3-none-any.whl (23 kB)
# Collecting dbt-bigquery
#   Downloading dbt_bigquery-1.0.0-py3-none-any.whl (34 kB)
# Collecting dbt-sqlite
#   Downloading dbt_sqlite-1.0.0-py3-none-any.whl (18 kB)
# Collecting click<9,>=8
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 6.5 MB/s
# Collecting hologram==0.0.14
#   Downloading hologram-0.0.14-py3-none-any.whl (11 kB)
# Requirement already satisfied: Jinja2==2.11.3 in /usr/local/lib/python3.7/dist-packages (from dbt-core) (2.11.3)
# Collecting dbt-extractor==0.4.0
#   Downloading dbt_extractor-0.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 46.0 MB/s
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.7/dist-packages (from dbt-core) (2.23.0)
# Requirement already satisfied: werkzeug<3,>=1 in /usr/local/lib/python3.7/dist-packages (from dbt-core) (1.0.1)
# Requirement already satisfied: networkx<3,>=2.3 in /usr/local/lib/python3.7/dist-packages (from dbt-core) (2.6.3)
# Collecting colorama<0.4.5,>=0.3.9
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /usr/local/lib/python3.7/dist-packages (from dbt-core) (1.15.0)
# Requirement already satisfied: sqlparse<0.5,>=0.2.3 in /usr/local/lib/python3.7/dist-packages (from dbt-core) (0.4.2)
# Collecting agate<1.6.4,>=1.6
#   Downloading agate-1.6.3-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 9.6 MB/s
# Collecting logbook<1.6,>=1.5
#   Downloading Logbook-1.5.3.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 4.0 MB/s
# Collecting minimal-snowplow-tracker==0.0.2
#   Downloading minimal-snowplow-tracker-0.0.2.tar.gz (12 kB)
# Collecting isodate<0.7,>=0.6
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 526 kB/s
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from dbt-core) (2.10)
# Requirement already satisfied: packaging<22.0,>=20.9 in /usr/local/lib/python3.7/dist-packages (from dbt-core) (21.3)
# Collecting mashumaro==2.9
#   Downloading mashumaro-2.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: typing-extensions<3.11,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from dbt-core) (3.10.0.2)
# Requirement already satisfied: MarkupSafe==2.0.1 in /usr/local/lib/python3.7/dist-packages (from dbt-core) (2.0.1)
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from hologram==0.0.14->dbt-core) (2.8.2)
# Collecting jsonschema<3.2,>=3.0
#   Downloading jsonschema-3.1.1-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.3 MB/s
# Requirement already satisfied: pyyaml>=3.13 in /usr/local/lib/python3.7/dist-packages (from mashumaro==2.9->dbt-core) (3.13)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.7/dist-packages (from mashumaro==2.9->dbt-core) (1.0.3)
# Requirement already satisfied: six<2.0,>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from minimal-snowplow-tracker==0.0.2->dbt-core) (1.15.0)
# Requirement already satisfied: python-slugify>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from agate<1.6.4,>=1.6->dbt-core) (5.0.2)
# Requirement already satisfied: Babel>=2.0 in /usr/local/lib/python3.7/dist-packages (from agate<1.6.4,>=1.6->dbt-core) (2.9.1)
# Collecting leather>=0.3.2
#   Downloading leather-0.3.4-py2.py3-none-any.whl (31 kB)
# Collecting pytimeparse>=1.1.5
#   Downloading pytimeparse-1.1.8-py2.py3-none-any.whl (10.0 kB)
# Collecting parsedatetime!=2.5,!=2.6,>=2.1
#   Downloading parsedatetime-2.4.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 3.4 MB/s
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/dist-packages (from Babel>=2.0->agate<1.6.4,>=1.6->dbt-core) (2018.9)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi<2.0.0,>=1.9->dbt-core) (2.21)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click<9,>=8->dbt-core) (4.11.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<3.2,>=3.0->hologram==0.0.14->dbt-core) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<3.2,>=3.0->hologram==0.0.14->dbt-core) (21.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jsonschema<3.2,>=3.0->hologram==0.0.14->dbt-core) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging<22.0,>=20.9->dbt-core) (3.0.7)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from parsedatetime!=2.5,!=2.6,>=2.1->agate<1.6.4,>=1.6->dbt-core) (0.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify>=1.2.1->agate<1.6.4,>=1.6->dbt-core) (1.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->dbt-core) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->dbt-core) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0->dbt-core) (1.24.3)
# Collecting psycopg2-binary~=2.8
#   Downloading psycopg2_binary-2.9.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 34.5 MB/s
# Collecting boto3<2.0.0,>=1.4.4
#   Downloading boto3-1.21.3-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 55.0 MB/s
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.1-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.3 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.25.0,>=1.24.3
#   Downloading botocore-1.24.3-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 45.7 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 51.4 MB/s
# Collecting snowflake-connector-python[secure-local-storage]<2.8.0,>=2.4.1
#   Downloading snowflake_connector_python-2.7.4-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#      |████████████████████████████████| 16.5 MB 41.2 MB/s
# Collecting cryptography<4,>=3.2
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 40.5 MB/s
# Collecting oscrypto<2.0.0
#   Downloading oscrypto-1.2.1-py2.py3-none-any.whl (192 kB)
#      |████████████████████████████████| 192 kB 71.5 MB/s
# Collecting pyjwt<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting pyOpenSSL<22.0.0,>=16.2.0
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.7 MB/s
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from snowflake-connector-python[secure-local-storage]<2.8.0,>=2.4.1->dbt-snowflake) (2.0.11)
# Collecting pycryptodomex!=3.5.0,<4.0.0,>=3.2
#   Downloading pycryptodomex-3.14.1-cp35-abi3-manylinux2010_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 40.6 MB/s
# Collecting asn1crypto<2.0.0,>0.24.0
#   Downloading asn1crypto-1.4.0-py2.py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 58.8 MB/s
# Collecting keyring!=16.1.0,<24.0.0
#   Downloading keyring-23.5.0-py3-none-any.whl (33 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.0 MB/s
# Collecting SecretStorage>=3.2
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click<9,>=8->dbt-core) (3.7.0)
# Requirement already satisfied: google-api-core<3,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from dbt-bigquery) (1.26.3)
# Collecting google-cloud-bigquery<3,>=1.25.0
#   Downloading google_cloud_bigquery-2.34.0-py2.py3-none-any.whl (206 kB)
#      |████████████████████████████████| 206 kB 49.7 MB/s
# Collecting google-cloud-core<3,>=1.3.0
#   Downloading google_cloud_core-2.2.2-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: googleapis-common-protos<2,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from dbt-bigquery) (1.54.0)
# Requirement already satisfied: protobuf<4,>=3.13.0 in /usr/local/lib/python3.7/dist-packages (from dbt-bigquery) (3.17.3)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3,>=1.16.0->dbt-bigquery) (1.35.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3,>=1.16.0->dbt-bigquery) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3,>=1.16.0->dbt-bigquery) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3,>=1.16.0->dbt-bigquery) (4.2.4)
# Requirement already satisfied: grpcio<2.0dev,>=1.38.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery<3,>=1.25.0->dbt-bigquery) (1.43.0)
# Collecting google-api-core[grpc]<3.0.0dev,>=1.29.0
#   Downloading google_api_core-2.5.0-py2.py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 47.4 MB/s
# Collecting google-resumable-media<3.0dev,>=0.6.0
#   Downloading google_resumable_media-2.2.1-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 3.6 MB/s
# Collecting proto-plus>=1.10.0
#   Downloading proto_plus-1.20.3-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 2.9 MB/s
# Collecting grpcio-status<2.0dev,>=1.33.2
#   Downloading grpcio_status-1.44.0-py3-none-any.whl (10.0 kB)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.3.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38 kB)
# Collecting grpcio<2.0dev,>=1.38.1
#   Downloading grpcio-1.44.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 48.8 MB/s
# Collecting protobuf<4,>=3.13.0
#   Downloading protobuf-3.19.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 20.7 MB/s
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<3,>=1.16.0->dbt-bigquery) (0.4.8)
# Building wheels for collected packages: minimal-snowplow-tracker, logbook, parsedatetime
#   Building wheel for minimal-snowplow-tracker (setup.py) ... done
#   Created wheel for minimal-snowplow-tracker: filename=minimal_snowplow_tracker-0.0.2-py3-none-any.whl size=17817 sha256=3f890d44e7f5c89d7d4cd6cba4f1fa60d511963b8e246f560c74580be3332f1f
#   Stored in directory: /root/.cache/pip/wheels/9d/ee/55/8faefee41ca3bccb25152e0159002567575047be7ef1ce8ac1
#   Building wheel for logbook (setup.py) ... done
#   Created wheel for logbook: filename=Logbook-1.5.3-cp37-cp37m-linux_x86_64.whl size=66394 sha256=b884bd4441e94119ae369e0edf07734b52033f201cc3b06aadd5704939538b81
#   Stored in directory: /root/.cache/pip/wheels/95/4b/a3/fc9b9d17a06a956767a8dc74058ba64d4306653df2289094cc
#   Building wheel for parsedatetime (setup.py) ... done
#   Created wheel for parsedatetime: filename=parsedatetime-2.4-py3-none-any.whl size=42773 sha256=3fd614d09acae356a0436d90028522c38b1216021c29783f5d42d8ad3241507c
#   Stored in directory: /root/.cache/pip/wheels/68/0f/b7/539a31a4068565a53913d7f8cfc6c7521cca2ea091b8a72048
# Successfully built minimal-snowplow-tracker logbook parsedatetime
# Installing collected packages: urllib3, protobuf, pytimeparse, parsedatetime, leather, jsonschema, jmespath, jeepney, isodate, grpcio, cryptography, asn1crypto, SecretStorage, pyOpenSSL, pyjwt, pycryptodomex, oscrypto, minimal-snowplow-tracker, mashumaro, logbook, hologram, grpcio-status, google-crc32c, google-api-core, dbt-extractor, colorama, click, botocore, agate, snowflake-connector-python, s3transfer, psycopg2-binary, proto-plus, keyring, google-resumable-media, google-cloud-core, dbt-core, google-cloud-bigquery, dbt-postgres, boto3, dbt-sqlite, dbt-snowflake, dbt-redshift, dbt-bigquery
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.43.0
#     Uninstalling grpcio-1.43.0:
#       Successfully uninstalled grpcio-1.43.0
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 1.26.3
#     Uninstalling google-api-core-1.26.3:
#       Successfully uninstalled google-api-core-1.26.3
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 0.4.1
#     Uninstalling google-resumable-media-0.4.1:
#       Successfully uninstalled google-resumable-media-0.4.1
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 1.0.3
#     Uninstalling google-cloud-core-1.0.3:
#       Successfully uninstalled google-cloud-core-1.0.3
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 1.21.0
#     Uninstalling google-cloud-bigquery-1.21.0:
#       Successfully uninstalled google-cloud-bigquery-1.21.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# pandas-gbq 0.13.3 requires google-cloud-bigquery[bqstorage,pandas]<2.0.0dev,>=1.11.1, but you have google-cloud-bigquery 2.34.0 which is incompatible.
# nbclient 0.5.10 requires jupyter-client>=6.1.5, but you have jupyter-client 5.3.5 which is incompatible.
# google-cloud-translate 1.5.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.5.0 which is incompatible.
# google-cloud-translate 1.5.0 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.2.2 which is incompatible.
# google-cloud-storage 1.18.1 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.2.2 which is incompatible.
# google-cloud-storage 1.18.1 requires google-resumable-media<0.5.0dev,>=0.3.1, but you have google-resumable-media 2.2.1 which is incompatible.
# google-cloud-language 1.2.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.5.0 which is incompatible.
# google-cloud-firestore 1.7.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.5.0 which is incompatible.
# google-cloud-firestore 1.7.0 requires google-cloud-core<2.0dev,>=1.0.3, but you have google-cloud-core 2.2.2 which is incompatible.
# google-cloud-datastore 1.8.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.5.0 which is incompatible.
# google-cloud-datastore 1.8.0 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.2.2 which is incompatible.
# google-cloud-bigquery-storage 1.1.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.5.0 which is incompatible.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.0.4 which is incompatible.
# firebase-admin 4.4.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0; platform_python_implementation != "PyPy", but you have google-api-core 2.5.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed SecretStorage-3.3.1 agate-1.6.3 asn1crypto-1.4.0 boto3-1.21.3 botocore-1.24.3 click-8.0.4 colorama-0.4.4 cryptography-3.4.8 dbt-bigquery-1.0.0 dbt-core-1.0.2 dbt-extractor-0.4.0 dbt-postgres-1.0.2 dbt-redshift-1.0.0 dbt-snowflake-1.0.0 dbt-sqlite-1.0.0 google-api-core-2.5.0 google-cloud-bigquery-2.34.0 google-cloud-core-2.2.2 google-crc32c-1.3.0 google-resumable-media-2.2.1 grpcio-1.44.0 grpcio-status-1.44.0 hologram-0.0.14 isodate-0.6.1 jeepney-0.7.1 jmespath-0.10.0 jsonschema-3.1.1 keyring-23.5.0 leather-0.3.4 logbook-1.5.3 mashumaro-2.9 minimal-snowplow-tracker-0.0.2 oscrypto-1.2.1 parsedatetime-2.4 proto-plus-1.20.3 protobuf-3.19.4 psycopg2-binary-2.9.3 pyOpenSSL-21.0.0 pycryptodomex-3.14.1 pyjwt-2.3.0 pytimeparse-1.1.8 s3transfer-0.5.1 snowflake-connector-python-2.7.4 urllib3-1.25.11
# installed version: 1.0.2
#    latest version: 1.0.2
#
# Up to date!
#
# Plugins:
#   - sqlite: 1.0.0 - Up to date!
#   - bigquery: 1.0.0 - Up to date!
#   - redshift: 1.0.0 - Up to date!
#   - postgres: 1.0.2 - Up to date!
#   - snowflake: 1.0.0 - Up to date!

# %%
import os
os.chdir("/content/")
# !git init dbt-tutorial
os.chdir("/content/dbt-tutorial")
# !dbt init jaffle_shop
# Out:
# Initialized empty Git repository in /content/dbt-tutorial/.git/
# 00:08:48  Running with dbt=1.0.2
# 00:08:48  Creating dbt configuration folder at /root/.dbt
# Which database would you like to use?
# [1] sqlite
# [2] bigquery
# [3] redshift
# [4] postgres
# [5] snowflake
#
# (Don't see the one you want? https://docs.getdbt.com/docs/available-adapters)
#
# Enter a number: 1
# 00:08:58  Profile jaffle_shop written to /root/.dbt/profiles.yml using target's sample configuration. Once updated, you'll be able to start developing with dbt.
# 00:08:58
# Your new dbt project "jaffle_shop" was created!
#
# For more information on how to configure the profiles.yml file,
# please consult the dbt documentation here:
#
#   https://docs.getdbt.com/docs/configure-your-profile
#
# One more thing:
#
# Need help? Don't hesitate to reach out to us via GitHub issues or on Slack:
#
#   https://community.getdbt.com/
#
# Happy modeling!

# %%
sql_file = open("/content/dbt-tutorial/jaffle_shop/models/customers.sql", "w")
n = sql_file.write("""with customers as (

    select
        id as customer_id,
        first_name,
        last_name

    from `dbt-tutorial`.jaffle_shop.customers

),

orders as (

    select
        id as order_id,
        user_id as customer_id,
        order_date,
        status

    from `dbt-tutorial`.jaffle_shop.orders

),

customer_orders as (

    select
        customer_id,

        min(order_date) as first_order_date,
        max(order_date) as most_recent_order_date,
        count(order_id) as number_of_orders

    from orders

    group by 1

),


final as (

    select
        customers.customer_id,
        customers.first_name,
        customers.last_name,
        customer_orders.first_order_date,
        customer_orders.most_recent_order_date,
        coalesce(customer_orders.number_of_orders, 0) as number_of_orders

    from customers

    left join customer_orders using (customer_id)

)

select * from final""".replace("""`dbt-tutorial`.""",""))
sql_file.close()

# %%
# check the current profiles.yml
# !cat ~/.dbt/profiles.yml
sql_file = open("/root/.dbt/profiles.yml", "w")
n = sql_file.write("""jaffle_shop:
  outputs:

    dev:
      type: sqlite
      threads: 1
      database: <database name>
      schema: 'main'
      schemas_and_paths:
        main: '/my_project/data/etl.db'
      schema_directory: '/my_project/data'

    prod:
      type: sqlite
      threads: 1
      database: <database name>
      schema: 'main'
      schemas_and_paths:
        main: '/my_project/data/etl.db'
      schema_directory: '/my_project/data'

  target: dev

jaffle_shop:
  outputs:

    dev:
      type: sqlite
      threads: 1
      database: <database name>
      schema: 'main'
      schemas_and_paths:
        main: '/my_project/data/etl.db'
      schema_directory: '/my_project/data'

    prod:
      type: sqlite
      threads: 1
      database: <database name>
      schema: 'main'
      schemas_and_paths:
        main: '/my_project/data/etl.db'
      schema_directory: '/my_project/data'

  target: dev""")
sql_file.close()
# !dbt run
# Out:
# jaffle_shop:
#   outputs:
#
#     dev:
#       type: sqlite
#       threads: 1
#       database: <database name>
#       schema: 'main'
#       schemas_and_paths:
#         main: '/my_project/data/etl.db'
#       schema_directory: '/my_project/data'
#
#     prod:
#       type: sqlite
#       threads: 1
#       database: <database name>
#       schema: 'main'
#       schemas_and_paths:
#         main: '/my_project/data/etl.db'
#       schema_directory: '/my_project/data'
#
#   target: dev
#
# jaffle_shop:
#   outputs:
#
#     dev:
#       type: sqlite
#       threads: 1
#       database: <database name>
#       schema: 'main'
#       schemas_and_paths:
#         main: '/my_project/data/etl.db'
#       schema_directory: '/my_project/data'
#
#     prod:
#       type: sqlite
#       threads: 1
#       database: <database name>
#       schema: 'main'
#       schemas_and_paths:
#         main: '/my_project/data/etl.db'
#       schema_directory: '/my_project/data'
#
#   target: dev

# %% [markdown]
# # Create SQLite DB

# %%
import sqlite3
from sqlite3 import Error
def create_connection(db_file):
    """ create a database connection to a SQLite database
    https://www.sqlitetutorial.net/sqlite-python/creating-database/ """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        if conn:
            conn.close()

main  = "/my_project/data/etl.db"
from pathlib import Path
Path("/my_project/data/").mkdir(parents=True, exist_ok=True)
create_connection(main)
# Out:
# 2.6.0

# %%
os.chdir("/content/dbt-tutorial/jaffle_shop")
# !ls
# !dbt run
# Out:
# analyses  dbt_project.yml  macros  models  README.md  seeds  snapshots	tests
# 00:13:10  Running with dbt=1.0.2
# 00:13:10  Partial parse save file not found. Starting full parse.
# 00:13:11  Found 3 models, 4 tests, 0 snapshots, 0 analyses, 171 macros, 0 operations, 0 seed files, 0 sources, 0 exposures, 0 metrics
# 00:13:11
# 00:13:11  Concurrency: 1 threads (target='dev')
# 00:13:11
# 00:13:11  1 of 3 START view model main.customers.......................................... [RUN]
# 00:13:11  1 of 3 OK created view model main.customers..................................... [OK in 0.05s]
# 00:13:11  2 of 3 START table model main.my_first_dbt_model................................ [RUN]
# 00:13:11  2 of 3 OK created table model main.my_first_dbt_model........................... [OK in 0.04s]
# 00:13:11  3 of 3 START view model main.my_second_dbt_model................................ [RUN]
# 00:13:11  3 of 3 OK created view model main.my_second_dbt_model........................... [OK in 0.03s]
# 00:13:11
# 00:13:11  Finished running 2 view models, 1 table model in 0.25s.
# 00:13:11
# 00:13:11  Completed successfully
# 00:13:11
# 00:13:11  Done. PASS=3 WARN=0 ERROR=0 SKIP=0 TOTAL=3

# %%
con = sqlite3. connect(main)
cursor = con. cursor()
cursor. execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor. fetchall())
cursor. execute("SELECT * FROM my_first_dbt_model;")
print(cursor. fetchall())
cursor. execute("SELECT sql FROM sqlite_master WHERE type = 'view';")
print(cursor. fetchall())
# Out:
# [('my_first_dbt_model',)]
# [(1,), (None,)]
# [('CREATE VIEW "customers" as\n    with customers as (\n\n    select\n        id as customer_id,\n        first_name,\n        last_name\n\n    from jaffle_shop.customers\n\n),\n\norders as (\n\n    select\n        id as order_id,\n        user_id as customer_id,\n        order_date,\n        status\n\n    from jaffle_shop.orders\n\n),\n\ncustomer_orders as (\n\n    select\n        customer_id,\n\n        min(order_date) as first_order_date,\n        max(order_date) as most_recent_order_date,\n        count(order_id) as number_of_orders\n\n    from orders\n\n    group by 1\n\n),\n\n\nfinal as (\n\n    select\n        customers.customer_id,\n        customers.first_name,\n        customers.last_name,\n        customer_orders.first_order_date,\n        customer_orders.most_recent_order_date,\n        coalesce(customer_orders.number_of_orders, 0) as number_of_orders\n\n    from customers\n\n    left join customer_orders using (customer_id)\n\n)\n\nselect * from final',), ('CREATE VIEW "my_second_dbt_model" as\n    -- Use the `ref` function to select from other models\n\nselect *\nfrom main."my_first_dbt_model"\nwhere id = 1',)]

# %%
# complete tutorial, delete projects
# !rm -rf /content/dbt-tutorial
